# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
prodata = pd.read_csv('prodata_refined.csv')
prodata
# Out:
#               Team     Player                              Game  \
# 0         Streamer    n0thing  Counter Strike: Global Offensive
# 1         Streamer     shroud  Counter Strike: Global Offensive
# 2           EG (S)   Stewie2k  Counter Strike: Global Offensive
# 3           Titans        MSL  Counter Strike: Global Offensive
# 4         Vitality     Magisk  Counter Strike: Global Offensive
# ..             ...        ...                               ...
# 737       Streamer  iiTzTimmy                          VALORANT
# 738             FA   governor                          VALORANT
# 739  MAD Lions (B)        xms                          VALORANT
# 740        NIP (B)       xand                          VALORANT
# 741   Heretics (S)    SirMaza                          VALORANT
#
#                                  Mouse Mouse HZ    DPI  Sensitivity   eDPI  \
# 0                Logitech G100s Custom      500    400         2.00    800
# ...

# %%
monitors = prodata.groupby(by=prodata['Monitor']) #Count of monitor used for each game
monitors2 = monitors['Game'].value_counts()

# %%
monitors2.plot(kind = 'bar', title = 'Monitors used by CSGO and Valorant Players',
              xlabel ='Monitor Brand',ylabel = 'Monitor Brand',figsize=(14, 6))
# Out:
# <AxesSubplot:title={'center':'Monitors used by CSGO and Valorant Players'}, xlabel='Monitor Brand', ylabel='Monitor Brand'>

# %%
val = prodata[prodata['Game']== 'VALORANT']
monitors3 = val['Monitor'].value_counts()
monitors3.plot(kind = 'bar', title = 'Monitors used by Valorant Players',
              xlabel ='Monitor Brand',ylabel = 'Monitor Brand',figsize=(14, 6))
# Out:
# <AxesSubplot:title={'center':'Monitors used by Valorant Players'}, xlabel='Monitor Brand', ylabel='Monitor Brand'>

# %%
csgo = prodata[prodata['Game']== 'Counter Strike: Global Offensive']
monitors4 = csgo['Monitor'].value_counts()
monitors4.plot(kind = 'bar', title = 'Monitors used by CSGO Players',
              xlabel ='Monitor Brand',ylabel = 'Monitor Brand',figsize=(14, 6))
# Out:
# <AxesSubplot:title={'center':'Monitors used by CSGO Players'}, xlabel='Monitor Brand', ylabel='Monitor Brand'>
