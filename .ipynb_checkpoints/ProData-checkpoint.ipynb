# %%
import pandas as pd
from bs4 import BeautifulSoup as bs
import requests
import csv

# %%
url = 'https://prosettings.net/cs-go-pro-settings-gear-list/'
page = requests.get(url)
page
# Out:
# <Response [200]>

# %%
soup = bs(page.content,"html.parser")
soup.title.text
# Out:
# 'CS:GO Pro Settings & Gear List'

# %%
#code to grab data from tables
table = soup.find('table',{'id':'table_1'})
headers =[]
for i in table.find_all('th'):
    col = i.text.strip()
    headers.append(col)
headers
# Out:
# ['Rank',
#  'Team',
#  'Player',
#  'Role',
#  'Mouse',
#  'M. HZ',
#  'DPI',
#  'Sens',
#  'eDPI',
#  'Zoom Sens',
#  'Accel',
#  'Win Sens',
#  'Raw input',
#  'Monitor',
#  'HZ',
#  'GPU',
#  'Resolution',
#  'Aspect Ratio',
#  'Scaling Mode',
#  'Mousepad',
#  'Keyboard',
#  'Headset',
#  'CFG']

# %%
#create dataframe with headers from table
df = pd.DataFrame(columns = headers)
df
# Out:
# Empty DataFrame
# Columns: [Rank, Team, Player, Role, Mouse, M. HZ, DPI, Sens, eDPI, Zoom Sens, Accel, Win Sens, Raw input, Monitor, HZ, GPU, Resolution, Aspect Ratio, Scaling Mode, Mousepad, Keyboard, Headset, CFG]
# Index: []
#
# [0 rows x 23 columns]

# %%
#loop through each row and grab td tags from table to populate each row in the df
for row in table.find_all('tr')[1:]: #exclude header
    data = row.find_all('td')
    row_data = [td.text.strip() for td in data]
    length = len(df)
    df.loc[length] = row_data
df = df[:510]
df
# Out:
#       Rank        Team    Player    Role                                Mouse  \
# 0    1,002    Streamer   n0thing  Rifler                Logitech G100s Custom
# 1    1,002    Streamer    shroud  Rifler         Logitech G303 Shroud Edition
# 2       34      EG (S)  Stewie2k  Rifler    Logitech G Pro X Superlight Black
# 3       50      Titans       MSL  Rifler           Zowie EC2-B Divina Edition
# 4       11    Vitality    Magisk  Rifler              Razer DeathAdder V3 Pro
# ..     ...         ...       ...     ...                                  ...
# 504    178         K23    Raijin  Rifler  Logitech G Pro X Superlight Magenta
# 505     37      Sangal      kory  Rifler    Logitech G Pro X Superlight Black
# 506     37      Sangal    ScrunK  Rifler                          ZOWIE FK2-B
# 507     41      Nemiga    fostar  Rifler    Logitech G Pro X Superlight Black
# 508  1,000  Free Agent     mertz  Rifler                            Zowie FK1
#
#      M. HZ  DPI  Sens   eDPI Zoom Sens  ...                 Monitor   HZ  \
# 0      500  400  2.00    800      1.00  ...       Alienware AW2521H  360
# 1    1,000  450  2.40  1,080      1.00  ...  ASUS ROG Swift PG27AQN  360
# 2    1,000  400  2.00    800      1.10  ...            BenQ XL2546K  360
# 3    1,000  400  1.60    640      1.00  ...             BenQ XL2546  240
# 4    4,000  800  1.00    800      1.18  ...             BenQ XL2546  240
# ..     ...  ...   ...    ...       ...  ...                     ...  ...
# 504                                     ...            BenQ XL2546K
# 505  1,000  800  1.50  1,200      1.00  ...            BenQ XL2546K  240
# 506  1,000  800  1.05    840      1.00  ...            BenQ XL2546K  240
# 507  1,000  800  1.34  1,072      1.00  ...            BenQ XL2546K  240
# 508  1,000  400  2.40    960      1.00  ...            BenQ XL2546K  240
#
#                 GPU Resolution Aspect Ratio Scaling Mode  \
# 0          RTX 3090  1920x1080         16:9
# 1          RTX 3090  2560x1440         16:9
# 2    RTX 2080 Super   1024x768          4:3           BB
# 3       GTX 1080 Ti   1280x960          4:3          STR
# 4          RTX 3080  1680x1050        16:10           BB
# ..              ...        ...          ...          ...
# 504                  1920x1080         16:9
# 505                   1280x960          4:3          STR
# 506                  1280x1024          5:4          STR
# 507                   1152x864          4:3           BB
# 508                   1024x768          4:3           BB
#
#                     Mousepad                              Keyboard  \
# 0      SteelSeries QcK Heavy                    HyperX Alloy Elite
# 1           Logitech G840 SE                Logitech G Pro X MK SE
# 2      SteelSeries QcK Heavy                         Logitech G512
# 3      SteelSeries QcK Heavy             SteelSeries APEX M750 TKL
# 4               VAXEE PA Y22                 Razer Huntsman V2 TKL
# ..                       ...                                   ...
# 504
# 505            Logitech G640
# 506              ZOWIE GTF-X                         Logitech G512
# 507  HATOR NAVI Out of Space  Logitech G Pro X Mechanical Keyboard
# 508    SteelSeries QcK Heavy             SteelSeries APEX M750 TKL
#
#                                   Headset     CFG
# 0    Logitech G Pro X Wireless Headset SE  CONFIG
# 1    Logitech G Pro X Wireless Headset SE  CONFIG
# 2                         HyperX Cloud II  CONFIG
# 3                  SteelSeries Arctis Pro  CONFIG
# 4                            Corsair HS80  CONFIG
# ..                                    ...     ...
# 504
# 505
# 506              Logitech G Pro X Headset
# 507              Logitech G Pro X Headset  CONFIG
# 508                       HyperX Cloud II  CONFIG
#
# [509 rows x 23 columns]

# %%
#grab valorant player HTML
url2 = 'https://prosettings.net/valorant-pro-settings-gear-list/'
page2 = requests.get(url2)
print(page2)

soup = bs(page2.content,"html.parser")
print(soup.title.text)
# Out:
# <Response [200]>
# VALORANT Pro Settings & Gear List

# %%
#Grab player data from tables

#Headers
table = soup.find('table',{'id':'table_1'})
headers =[]
for i in table.find_all('th'):
    col = i.text.strip()
    headers.append(col)
headers

#DataFrame for valorant Players
df2 = pd.DataFrame(columns = headers)
df2
# Out:
# Empty DataFrame
# Columns: [rank, Team, wdt_ID, Name, Mouse, HZ, DPI, Sensitivity, eDPI, Scoped Sensitivity, Monitor, Monitor HZ, GPU, Resolution, Mousepad, Keyboard, Headset]
# Index: []

# %%
#loop through rows and grab necessary data to populate rows in df
for row in table.find_all('tr')[1:]:
    data = row.find_all('td')
    row_data = [td.text.strip() for td in data]
    length = len(df2)
    df2.loc[length] = row_data
df2 = df2[:]
df2
# Out:
#       rank          Team  wdt_ID       Name  \
# 0    1,000      Streamer       1     shroud
# 1    1,000      Streamer       2   summit1g
# 2      126        T1 (S)       3       Brax
# 3    1,000      Streamer       4    n0thing
# 4      999            FA       5  Skadoodle
# ..     ...           ...     ...        ...
# 348     21       NIP (B)     385       xand
# 349    119  Angry Titans     386       ngiN
# 350    121    Fokus Clan     387       JUGi
# 351     47  Heretics (S)     389    SirMaza
# 352   rank          Team  wdt_ID       Name
#
#                                   Mouse     HZ  DPI  Sensitivity  eDPI  \
# 0          Logitech G303 Shroud Edition  1,000  400        0.800   320
# 1    FinalMouse Air58 Ninja CBR Edition    500  400        0.415   166
# 2                        Logitech MX518  1,000  400        0.550   220
# 3                 Logitech G100s Custom  1,000  400        0.645   258
# 4     Logitech G Pro X Superlight Black    500  400        0.600   240
# ..                                  ...    ...  ...          ...   ...
# 348         Logitech G Pro X Superlight  1,000  800        0.510   408
# 349             Razer DeathAdder V3 Pro  1,000  800        0.244   195
# 350              Logitech G403 Wireless  1,000  700        0.251   175
# 351         Logitech G Pro X Superlight  1,000  400        0.500   200
# 352                               Mouse     HZ  DPI  Sensitivity  eDPI
#
#      Scoped Sensitivity             Monitor  Monitor HZ             GPU  \
# 0                 1.000   Alienware AW2721D         240        RTX 3090
# 1                 1.000  Samsung Odyssey G7         240     RTX 2080 Ti
# 2                 1.000        BenQ XL2546S         240     RTX 2080 Ti
# 3                 1.000   Alienware AW2521H         240        RTX 3090
# 4                 1.000         BenQ XL2546         240        RTX 2080
# ..                  ...                 ...         ...             ...
# 348               0.950        BenQ XL2546K         240  RTX 2070 Super
# 349               1.000         BenQ XL2540         240
# 350               1.000         BenQ XL2546         240
# 351               1.000        ASUS VG259QM         240        RTX 3080
# 352  Scoped Sensitivity             Monitor  Monitor HZ             GPU
#
#      Resolution               Mousepad                              Keyboard  \
# 0     2560x1440       Logitech G840 SE          Logitech G Pro X Keyboard SE
# 1     1920x1080          Corsair MM500                  Corsair K70 RGB MK.2
# 2     1920x1080  SteelSeries QcK Heavy  Logitech G Pro X Mechanical Keyboard
# 3     1920x1080          Logitech G440                Logitech G Pro X MK SE
# 4     1920x1080             Zowie G-SR  Logitech G Pro X Mechanical Keyboard
# ..          ...                    ...                                   ...
# 348   1920x1080         VAXEE PA ZYGEN                     Logitech G915 TKL
# 349   1920x1080               VAXEE PA               Razer BlackWidow V3 Pro
# 350                         Zowie G-SR                 SteelSeries Apex M500
# 351   1920x1080            ZOWIE GTF-X                  HyperX Alloy FPS Pro
# 352  Resolution               Mousepad                              Keyboard
#
#                                   Headset
# 0    Logitech G Pro X Wireless Headset SE
# 1               Audio Technica ATH-AD700X
# 2                       Sennheiser HD 600
# 3    Logitech G Pro X Wireless Headset SE
# 4                        Logitech G Pro X
# ..                                    ...
# 348                    HyperX Cloud Alpha
# 349                       HyperX Cloud II
# 350                  Sennheiser GAME ZERO
# 351           Beyerdynamic DT 880 Edition
# 352                               Headset
#
# [353 rows x 17 columns]

# %%
#export
#export_csv = df.to_csv(r'csgopros.csv',index = None, header = True)
export_csv2 = df2.to_csv(r'ValorantPros.csv',index = None, header = True)
