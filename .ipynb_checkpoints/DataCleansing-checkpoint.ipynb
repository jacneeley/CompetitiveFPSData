# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import csv

# %%
cs = pd.read_csv('csgopros.csv')
val = pd.read_csv('valorantpros.csv')

# %%
#count null values in cspro data
print(cs.isnull().sum()),
print('shape:',cs.shape)
# Out:
# Rank             0
# Team             0
# Player           0
# Role             0
# Mouse           12
# M. HZ           14
# DPI             13
# Sens            12
# eDPI            13
# Zoom Sens       12
# Accel           15
# Win Sens        17
# Raw input       13
# Monitor          6
# HZ              11
# GPU             89
# Resolution      21
# Aspect Ratio    22
# Scaling Mode    89
# Mousepad        28
# Keyboard        31
# Headset         29
# CFG             95
# dtype: int64
# shape: (510, 23)

# %%
#count null values in valorant pro data
print(val.isnull().sum()),
print('shape:',val.shape)
# Out:
# rank                   0
# Team                   0
# wdt_ID                 0
# Name                   0
# Mouse                  2
# HZ                     2
# DPI                    2
# Sensitivity            2
# eDPI                   3
# Scoped Sensitivity     8
# Monitor               24
# Monitor HZ            23
# GPU                   91
# Resolution            13
# Mousepad              14
# Keyboard              23
# Headset               39
# dtype: int64
# shape: (353, 17)

# %%
csheaders = list(cs.columns)
valheaders = list(val.columns)
ar1 = np.array(csheaders)
ar2 = np.array(valheaders)

#what columns do not appear in the other?
np.setdiff1d(ar2,ar1), np.setdiff1d(ar1,ar2)
# Out:
# (array(['Monitor HZ', 'Name', 'Scoped Sensitivity', 'Sensitivity', 'rank',
#         'wdt_ID'], dtype='<U18'),
#  array(['Accel', 'Aspect Ratio', 'CFG', 'M. HZ', 'Player', 'Rank',
#         'Raw input', 'Role', 'Scaling Mode', 'Sens', 'Win Sens',
#         'Zoom Sens'], dtype='<U12'))

# %%
#drop columns
cs = cs.drop(['CFG','Zoom Sens','Scaling Mode','Rank','Role','Raw input','Accel','Win Sens'],axis =1)

#rename columns
cs.rename(columns = {'HZ':'Monitor HZ','M. HZ':'Mouse HZ','Sens':'Sensitivity'},inplace = True)

# %%
#drop columns
val = val.drop(['wdt_ID','Scoped Sensitivity','rank'],axis=1)

#rename columns
val.rename(columns = {'HZ':'Mouse HZ'},inplace = True)

#drop row
val = val.drop(352) #this row contained headers as the values for some reason...

# %%
player_rez = []
for i in val['Resolution']:
    player_rez.append(i)
player_rez
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [52], in <cell line: 6>()
#       3     player_rez.append(i)
#       4 player_rez
# ----> 6 player_rez.map({['1280×720','1366×768','1600×900','1920×1080','2560×1440','3840×2160']:'16:9'})
#
# AttributeError: 'list' object has no attribute 'map'

# %%
cs.shape
# Out:
# (510, 15)

# %%
#insert aspect ratio column for valorant pro data - requires some data mining

#collect resolution from each player
player_rez = []
for i in val['Resolution']:
    player_rez.append(i)
player_rez

#player_rez.map({:'16:9',:'16:10',:'4:3',:'5:4'})

val.insert(
    loc = 11,
    column = 'Aspect Ratio',
    value = player_rez
)
val
# Out:
#              Team       Name                               Mouse Mouse HZ  \
# 0        Streamer     shroud        Logitech G303 Shroud Edition    1,000
# 1        Streamer   summit1g  FinalMouse Air58 Ninja CBR Edition      500
# 2          T1 (S)       Brax                      Logitech MX518    1,000
# 3        Streamer    n0thing               Logitech G100s Custom    1,000
# 4              FA  Skadoodle   Logitech G Pro X Superlight Black      500
# ..            ...        ...                                 ...      ...
# 347      Team BDS      logaN                           Zowie FK1    1,000
# 348       NIP (B)       xand         Logitech G Pro X Superlight    1,000
# 349  Angry Titans       ngiN             Razer DeathAdder V3 Pro    1,000
# 350    Fokus Clan       JUGi              Logitech G403 Wireless    1,000
# 351  Heretics (S)    SirMaza         Logitech G Pro X Superlight    1,000
#
#      DPI Sensitivity eDPI             Monitor Monitor HZ             GPU  \
# 0    400       0.800  320   Alienware AW2721D        240        RTX 3090
# 1    400       0.415  166  Samsung Odyssey G7        240     RTX 2080 Ti
# 2    400       0.550  220        BenQ XL2546S        240     RTX 2080 Ti
# 3    400       0.645  258   Alienware AW2521H        240        RTX 3090
# 4    400       0.600  240         BenQ XL2546        240        RTX 2080
# ..   ...         ...  ...                 ...        ...             ...
# 347  400       0.534  213        BenQ XL2411T        144             NaN
# 348  800       0.510  408        BenQ XL2546K        240  RTX 2070 Super
# 349  800       0.244  195         BenQ XL2540        240             NaN
# 350  700       0.251  175         BenQ XL2546        240             NaN
# 351  400       0.500  200        ASUS VG259QM        240        RTX 3080
#
#     Resolution Aspect Ratio               Mousepad  \
# 0    2560x1440    2560x1440       Logitech G840 SE
# 1    1920x1080    1920x1080          Corsair MM500
# 2    1920x1080    1920x1080  SteelSeries QcK Heavy
# 3    1920x1080    1920x1080          Logitech G440
# 4    1920x1080    1920x1080             Zowie G-SR
# ..         ...          ...                    ...
# 347        NaN          NaN             Zowie G-SR
# 348  1920x1080    1920x1080         VAXEE PA ZYGEN
# 349  1920x1080    1920x1080               VAXEE PA
# 350        NaN          NaN             Zowie G-SR
# 351  1920x1080    1920x1080            ZOWIE GTF-X
#
#                                  Keyboard  \
# 0            Logitech G Pro X Keyboard SE
# 1                    Corsair K70 RGB MK.2
# 2    Logitech G Pro X Mechanical Keyboard
# 3                  Logitech G Pro X MK SE
# 4    Logitech G Pro X Mechanical Keyboard
# ..                                    ...
# 347                 SteelSeries Apex M500
# 348                     Logitech G915 TKL
# 349               Razer BlackWidow V3 Pro
# 350                 SteelSeries Apex M500
# 351                  HyperX Alloy FPS Pro
#
#                                   Headset
# 0    Logitech G Pro X Wireless Headset SE
# 1               Audio Technica ATH-AD700X
# 2                       Sennheiser HD 600
# 3    Logitech G Pro X Wireless Headset SE
# 4                        Logitech G Pro X
# ..                                    ...
# 347                       HyperX Cloud II
# 348                    HyperX Cloud Alpha
# 349                       HyperX Cloud II
# 350                  Sennheiser GAME ZERO
# 351           Beyerdynamic DT 880 Edition
#
# [352 rows x 15 columns]

# %%
asp1 = [    '1024×576',
    '1152×648'
    '1280×720'
    '1366×768'
    '1600×900'
    '1920×1080'
    '2560×1440'
    '3840×2160']

#val['Aspect Ratio']=val['Aspect Ratio'].map({['1280×720','1366×768','1600×900','1920×1080','2560×1440','3840×2160']:'16:9',})
val
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [76], in <cell line: 10>()
#       1 asp1 = [    '1024×576',
#       2     '1152×648'
#       3     '1280×720'
#    (...)
#       7     '2560×1440'
#       8     '3840×2160']
# ---> 10 val['Aspect Ratio']=val['Aspect Ratio'].map({lambda asp1:'16:9'})
#      11 val
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py:4237, in Series.map(self, arg, na_action)
#    4162 def map(self, arg, na_action=None) -> Series:
#    4163     """
#    4164     Map values of Series according to an input mapping or function.
#    4165
#    (...)
#    4235     dtype: object
#    4236     """
# -> 4237     new_values = self._map_values(arg, na_action=na_action)
#    4238     return self._constructor(new_values, index=self.index).__finalize__(
#    4239         self, method="map"
#    4240     )
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\base.py:880, in IndexOpsMixin._map_values(self, mapper, na_action)
#     877         raise ValueError(msg)
#     879 # mapper is a function
# --> 880 new_values = map_f(values, mapper)
#     882 return new_values
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\lib.pyx:2870, in pandas._libs.lib.map_infer()
#
# TypeError: 'set' object is not callable

# %%
pd.value_counts(val['Aspect Ratio'])
# Out:
# 1920x1080     246
# 1280x960       37
# 1440x1080      14
# 1280x1024       9
# 1680x1050       8
# 1600x900        5
# 1024x768        4
# 1366x768        3
# 1600x1024       2
# 1280x768        2
# 2560x1440       2
# 1440x900        2
# 1798x1080       1
# 1280*960        1
# 1728x1080       1
# 1280 x 960      1
# 1280x1080       1
# Name: Aspect Ratio, dtype: int64

# %%
asp1 = [    '1024×576',
    '1152×648'
    '1280×720'
    '1366×768'
    '1600×900'
    '1920×1080'
    '2560×1440'
    '3840×2160']

for rez in val['Aspect Ratio']:
    if asp1.any(rez):
        print(true)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [85], in <cell line: 10>()
#       1 asp1 = [    '1024×576',
#       2     '1152×648'
#       3     '1280×720'
#    (...)
#       7     '2560×1440'
#       8     '3840×2160']
#      10 for rez in val['Aspect Ratio']:
# ---> 11     if asp1.any(rez):
#      12         print(true)
#
# AttributeError: 'list' object has no attribute 'any'
