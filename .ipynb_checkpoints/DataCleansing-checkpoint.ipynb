# %%
import pandas as pd
import numpy as np
import csv

# %%
cs = pd.read_csv('csgopros_raw.csv')
val = pd.read_csv('valorantpros_raw.csv')

# %%
#count null values in cspro data
print(cs.isnull().sum()),
print('shape:',cs.shape)

#TODO - fill m. hz, DPI, Sens,HZ,Resolution,Aspect Ratio with respective medians
# Out:
# Team            0
# Player          0
# Game            0
# Mouse           0
# Mouse HZ        0
# DPI             0
# Sensitivity     0
# eDPI            0
# Monitor         0
# Monitor HZ      0
# GPU             0
# Resolution      0
# Aspect Ratio    0
# Mousepad        0
# Keyboard        0
# Headset         0
# dtype: int64
# shape: (409, 16)

# %%
#count null values in valorant pro data
print(val.isnull().sum()),
print('shape:',val.shape)

#ToDO - Fill DPI,Sens,monitor hz, resolution/Aspect Ratio with median
# Out:
# Team             0
# Player           0
# Game             0
# Mouse            2
# Mouse HZ         2
# DPI              2
# Sensitivity      0
# eDPI             3
# Monitor         24
# Monitor HZ      23
# GPU             91
# Resolution       0
# Aspect Ratio     1
# Mousepad        14
# Keyboard        23
# Headset         39
# dtype: int64
# shape: (352, 16)

# %%
csheaders = list(cs.columns)
valheaders = list(val.columns)
ar1 = np.array(csheaders)
ar2 = np.array(valheaders)

#what columns do not appear in the other?
np.setdiff1d(ar2,ar1), np.setdiff1d(ar1,ar2)
# Out:
# (array([], dtype='<U12'), array([], dtype='<U12'))

# %%
#drop columns
cs = cs.drop(['CFG','Zoom Sens','Scaling Mode','Rank','Role','Raw input','Accel','Win Sens'],axis =1)

#rename columns
cs.rename(columns = {'HZ':'Monitor HZ','M. HZ':'Mouse HZ','Sens':'Sensitivity'},inplace = True)

#fill csgo nulls

#fill null Sens values
cs['Sensitivity'] = cs['Sensitivity'].astype(float)
cs['Sensitivity'] = cs['Sensitivity'].fillna(cs['Sensitivity'].median())

#fill resolution
rezlist=list(cs['Resolution'].unique())
rezmedian = rezlist[8] #median is 800x600
cs['Resolution'] = cs['Resolution'].fillna(rezmedian)

#fill aspect ratio - aspect ratio is derived from resolution
#aspect ratio of 800x600 = 800/600 = 8/6 = 4:3
cs['Aspect Ratio'] = cs['Aspect Ratio'].fillna('4:3')


#drop nulls that aren't fillable
#cs=cs.dropna()

#create game(specifies which game a pro primarily plays)
cs.insert(
    loc = 2,
    column = 'Game',
    value = 'Counter Strike: Global Offensive'
)
cs
# Out:
#                Team       Player                              Game  \
# 0          Streamer      n0thing  Counter Strike: Global Offensive
# 1          Streamer       shroud  Counter Strike: Global Offensive
# 2            EG (S)     Stewie2k  Counter Strike: Global Offensive
# 3            Titans          MSL  Counter Strike: Global Offensive
# 4          Vitality       Magisk  Counter Strike: Global Offensive
# ..              ...          ...                               ...
# 494        BLUEJAYS     CacaNito  Counter Strike: Global Offensive
# 497  Ambush Esports    devoduvek  Counter Strike: Global Offensive
# 498      Free Agent  dimaoneshot  Counter Strike: Global Offensive
# 499          Sangal      kyuubii  Counter Strike: Global Offensive
# 501       Rare Atom      Mercury  Counter Strike: Global Offensive
#
#                                  Mouse Mouse HZ  DPI  Sensitivity   eDPI  \
# 0                Logitech G100s Custom      500  400         2.00    800
# 1         Logitech G303 Shroud Edition    1,000  450         2.40  1,080
# 2    Logitech G Pro X Superlight Black    1,000  400         2.00    800
# 3           Zowie EC2-B Divina Edition    1,000  400         1.60    640
# 4              Razer DeathAdder V3 Pro    4,000  800         1.00    800
# ..                                 ...      ...  ...          ...    ...
# 494  Logitech G Pro X Superlight Black    1,000  400         1.50    600
# 497         Zowie EC2-B Divina Edition    1,000  400         1.80    720
# 498  Logitech G Pro X Superlight White    1,000  800         1.10    880
# 499  Logitech G Pro X Superlight Black    1,000  800         1.15    920
# 501                           Zowie S2    1,000  400         2.12    848
#
#                     Monitor  Monitor HZ             GPU Resolution  \
# 0         Alienware AW2521H       360.0        RTX 3090  1920x1080
# 1         Alienware AW2721D       240.0        RTX 3090  2560x1440
# 2              BenQ XL2546K       360.0  RTX 2080 Super   1024x768
# 3               BenQ XL2546       240.0     GTX 1080 Ti   1280x960
# 4               BenQ XL2546       240.0        RTX 3080  1680x1050
# ..                      ...         ...             ...        ...
# 494            BenQ XL2546K       240.0        RTX 2060  1280x1024
# 497  ASUS ROG Swift PG259QN       240.0        RTX 3080   1024x768
# 498            BenQ XL2546K       240.0     RTX 3080 Ti  1680x1050
# 499            BenQ XL2546K       240.0  RTX 2070 Super   1280x960
# 501            BenQ XL2546K       240.0        RTX 3080   1280x960
#
#     Aspect Ratio                    Mousepad  \
# 0           16:9       SteelSeries QcK Heavy
# 1           16:9            Logitech G840 SE
# 2            4:3       SteelSeries QcK Heavy
# 3            4:3       SteelSeries QcK Heavy
# 4          16:10                VAXEE PA Y22
# ..           ...                         ...
# 494          5:4               Logitech G640
# 497          4:3                  Zowie G-SR
# 498        16:10           VAXEE PA FunSpark
# 499          4:3  Endgame Gear MPJ450 Sprout
# 501          4:3                  Zowie G-SR
#
#                                  Keyboard  \
# 0                      HyperX Alloy Elite
# 1                  Logitech G Pro X MK SE
# 2                           Logitech G512
# 3               SteelSeries APEX M750 TKL
# 4                   Razer Huntsman V2 TKL
# ..                                    ...
# 494                         Logitech G513
# 497                    Zowie Celeritas II
# 498                          Xtrfy K2-RGB
# 499  Logitech G Pro X Mechanical Keyboard
# 501                  SteelSeries Apex Pro
#
#                                   Headset
# 0    Logitech G Pro X Wireless Headset SE
# 1    Logitech G Pro X Wireless Headset SE
# 2                         HyperX Cloud II
# 3                  SteelSeries Arctis Pro
# 4                            Corsair HS80
# ..                                    ...
# 494                       HyperX Cloud II
# 497                       HyperX Cloud II
# 498                    Sennheiser GSP 600
# 499                    Sennheiser GSP 500
# 501                       HyperX Cloud II
#
# [409 rows x 16 columns]

# %%
#drop columns
val = val.drop(['wdt_ID','Scoped Sensitivity','rank'],axis=1)

#rename columns
val.rename(columns = {'HZ':'Mouse HZ','Name':'Player'},inplace = True)

#drop row
val = val.drop(352) #this row contained headers as the values for some reason...

#fill null values in valorant data
val['Sensitivity'] = val['Sensitivity'].astype(float)
val['Sensitivity'] = val['Sensitivity'].fillna(val['Sensitivity'].median())

rezlist=list(val['Resolution'].unique())
rezmedian = rezlist[7]
val['Resolution'] = val['Resolution'].fillna(rezmedian)

#drop nulls
val=val.dropna()

# %%
#valorant does not contain a column for aspect ratio
#insert aspect ratio column for valorant pro data - requires some data mining

#obtain resolutions to calculate aspect ratio
player_rez = []
for i in val['Resolution']:
    player_rez.append(i)

#Aspect Ratio of an image is its width to its height - Resolution can be thought of as widthxheight
#divide width of resolution by resolution height to determine aspect ratio
rez=np.array(player_rez)
rez.astype(str)
aspect = []
for i in rez:
    r = i.split('x')
    num1 = int(r[0])
    num2 = int(r[1])
    asp = round(num1/num2,2)
    aspect.append(asp)
aspect



val.insert(
    loc = 11,
    column = 'Aspect Ratio',
    value = aspect
)

val['Aspect Ratio'] = val['Aspect Ratio'].fillna(val['Aspect Ratio'].median())

#insert game column(specifies which game a pro primarily plays)
val.insert(
    loc = 2,
    column = 'Game',
    value = 'VALORANT'
)

#16:9 is a very common aspect ratio, 16/9 = 1.777778; calculated values from aspect list are mapped to their respective ratios
val['Aspect Ratio'] = val['Aspect Ratio'].map({1.78:'16:9',1.25:'5:4',1.6:'16:10',1.33:'4:3',1.67:'16:10',1.56:'14:9',1.66:'16:10'})
val
# Out:
#              Team     Player      Game                               Mouse  \
# 0        Streamer     shroud  VALORANT        Logitech G303 Shroud Edition
# 1        Streamer   summit1g  VALORANT  FinalMouse Air58 Ninja CBR Edition
# 2          T1 (S)       Brax  VALORANT                      Logitech MX518
# 3        Streamer    n0thing  VALORANT               Logitech G100s Custom
# 4              FA  Skadoodle  VALORANT   Logitech G Pro X Superlight Black
# ..            ...        ...       ...                                 ...
# 347      Team BDS      logaN  VALORANT                           Zowie FK1
# 348       NIP (B)       xand  VALORANT         Logitech G Pro X Superlight
# 349  Angry Titans       ngiN  VALORANT             Razer DeathAdder V3 Pro
# 350    Fokus Clan       JUGi  VALORANT              Logitech G403 Wireless
# 351  Heretics (S)    SirMaza  VALORANT         Logitech G Pro X Superlight
#
#     Mouse HZ  DPI  Sensitivity eDPI             Monitor Monitor HZ  \
# 0      1,000  400        0.800  320   Alienware AW2721D        240
# 1        500  400        0.415  166  Samsung Odyssey G7        240
# 2      1,000  400        0.550  220        BenQ XL2546S        240
# 3      1,000  400        0.645  258   Alienware AW2521H        240
# 4        500  400        0.600  240         BenQ XL2546        240
# ..       ...  ...          ...  ...                 ...        ...
# 347    1,000  400        0.534  213        BenQ XL2411T        144
# 348    1,000  800        0.510  408        BenQ XL2546K        240
# 349    1,000  800        0.244  195         BenQ XL2540        240
# 350    1,000  700        0.251  175         BenQ XL2546        240
# 351    1,000  400        0.500  200        ASUS VG259QM        240
#
#                 GPU Resolution Aspect Ratio               Mousepad  \
# 0          RTX 3090  2560x1440         16:9       Logitech G840 SE
# 1       RTX 2080 Ti  1920x1080         16:9          Corsair MM500
# 2       RTX 2080 Ti  1920x1080         16:9  SteelSeries QcK Heavy
# 3          RTX 3090  1920x1080         16:9          Logitech G440
# 4          RTX 2080  1920x1080         16:9             Zowie G-SR
# ..              ...        ...          ...                    ...
# 347             NaN   1600x900         16:9             Zowie G-SR
# 348  RTX 2070 Super  1920x1080         16:9         VAXEE PA ZYGEN
# 349             NaN  1920x1080         16:9               VAXEE PA
# 350             NaN   1600x900         16:9             Zowie G-SR
# 351        RTX 3080  1920x1080         16:9            ZOWIE GTF-X
#
#                                  Keyboard  \
# 0            Logitech G Pro X Keyboard SE
# 1                    Corsair K70 RGB MK.2
# 2    Logitech G Pro X Mechanical Keyboard
# 3                  Logitech G Pro X MK SE
# 4    Logitech G Pro X Mechanical Keyboard
# ..                                    ...
# 347                 SteelSeries Apex M500
# 348                     Logitech G915 TKL
# 349               Razer BlackWidow V3 Pro
# 350                 SteelSeries Apex M500
# 351                  HyperX Alloy FPS Pro
#
#                                   Headset
# 0    Logitech G Pro X Wireless Headset SE
# 1               Audio Technica ATH-AD700X
# 2                       Sennheiser HD 600
# 3    Logitech G Pro X Wireless Headset SE
# 4                        Logitech G Pro X
# ..                                    ...
# 347                       HyperX Cloud II
# 348                    HyperX Cloud Alpha
# 349                       HyperX Cloud II
# 350                  Sennheiser GAME ZERO
# 351           Beyerdynamic DT 880 Edition
#
# [352 rows x 16 columns]

# %%
#concate dataframes into 1 refined dataframe
dfs= [cs,val]
prodata = pd.concat(dfs)
prodata
# Out:
#               Team     Player                              Game  \
# 0         Streamer    n0thing  Counter Strike: Global Offensive
# 1         Streamer     shroud  Counter Strike: Global Offensive
# 2           EG (S)   Stewie2k  Counter Strike: Global Offensive
# 3           Titans        MSL  Counter Strike: Global Offensive
# 4         Vitality     Magisk  Counter Strike: Global Offensive
# ..             ...        ...                               ...
# 344       Streamer  iiTzTimmy                          VALORANT
# 345             FA   governor                          VALORANT
# 346  MAD Lions (B)        xms                          VALORANT
# 348        NIP (B)       xand                          VALORANT
# 351   Heretics (S)    SirMaza                          VALORANT
#
#                                  Mouse Mouse HZ    DPI Sensitivity   eDPI  \
# 0                Logitech G100s Custom      500    400         2.0    800
# 1         Logitech G303 Shroud Edition    1,000    450         2.4  1,080
# 2    Logitech G Pro X Superlight Black    1,000    400         2.0    800
# 3           Zowie EC2-B Divina Edition    1,000    400         1.6    640
# 4              Razer DeathAdder V3 Pro    4,000    800         1.0    800
# ..                                 ...      ...    ...         ...    ...
# 344        Logitech G Pro X Superlight    1,000  1,800        0.19    342
# 345           FinalMouse Starlight Pro    1,000  1,200        0.45    540
# 346            Razer DeathAdder V3 Pro    1,000    800        0.45    360
# 348        Logitech G Pro X Superlight    1,000    800        0.51    408
# 351        Logitech G Pro X Superlight    1,000    400         0.5    200
#
#                Monitor Monitor HZ             GPU Resolution Aspect Ratio  \
# 0    Alienware AW2521H      360.0        RTX 3090  1920x1080         16:9
# 1    Alienware AW2721D      240.0        RTX 3090  2560x1440         16:9
# 2         BenQ XL2546K      360.0  RTX 2080 Super   1024x768          4:3
# 3          BenQ XL2546      240.0     GTX 1080 Ti   1280x960          4:3
# 4          BenQ XL2546      240.0        RTX 3080  1680x1050        16:10
# ..                 ...        ...             ...        ...          ...
# 344        BenQ XL2740        240     RTX 3080 Ti  1920x1080         16:9
# 345        BenQ XL2740        240     RTX 3070 Ti  1920x1080         16:9
# 346        BenQ XL2540        240        RTX 3080  1920x1080         16:9
# 348       BenQ XL2546K        240  RTX 2070 Super  1920x1080         16:9
# 351       ASUS VG259QM        240        RTX 3080  1920x1080         16:9
#
#                   Mousepad                   Keyboard  \
# 0    SteelSeries QcK Heavy         HyperX Alloy Elite
# 1         Logitech G840 SE     Logitech G Pro X MK SE
# 2    SteelSeries QcK Heavy              Logitech G512
# 3    SteelSeries QcK Heavy  SteelSeries APEX M750 TKL
# 4             VAXEE PA Y22      Razer Huntsman V2 TKL
# ..                     ...                        ...
# 344       Logitech G840 SE              Wooting 60 HE
# 345       SteelSeries QcK+           Ducky One 3 Mini
# 346             Zowie G-SR            Ducky One 2 RGB
# 348         VAXEE PA ZYGEN          Logitech G915 TKL
# 351            ZOWIE GTF-X       HyperX Alloy FPS Pro
#
#                                   Headset
# 0    Logitech G Pro X Wireless Headset SE
# 1    Logitech G Pro X Wireless Headset SE
# 2                         HyperX Cloud II
# 3                  SteelSeries Arctis Pro
# 4                            Corsair HS80
# ..                                    ...
# 344  Logitech G Pro X Wireless Headset SE
# 345               Beyerdynamic DT 990 Pro
# 346                       HyperX Cloud II
# 348                    HyperX Cloud Alpha
# 351           Beyerdynamic DT 880 Edition
#
# [635 rows x 16 columns]

# %%
#find duplicate rows if any
#number of total duplicates
prodata.duplicated(subset = 'Player',keep=False).sum()

#return rows of total duplicates
prodata[prodata['Player'].duplicated(keep = False)]
# Out:
#                Team     Player                              Game  \
# 0          Streamer    n0thing  Counter Strike: Global Offensive
# 1          Streamer     shroud  Counter Strike: Global Offensive
# 2            EG (S)   Stewie2k  Counter Strike: Global Offensive
# 32             NaVi     s1mple  Counter Strike: Global Offensive
# 41           Liquid      EliGE  Counter Strike: Global Offensive
# 46         Streamer     ScreaM  Counter Strike: Global Offensive
# 55             Case      steel  Counter Strike: Global Offensive
# 97         Streamer  seangares  Counter Strike: Global Offensive
# 169        Streamer       TenZ  Counter Strike: Global Offensive
# 192            HEET      Lucky  Counter Strike: Global Offensive
# 367  Tricked Esport      Lucky  Counter Strike: Global Offensive
# 0          Streamer     shroud                          VALORANT
# 3          Streamer    n0thing                          VALORANT
# 10           Liquid     ScreaM                          VALORANT
# 11        Sentinels       TenZ                          VALORANT
# 12       Liquid (S)      EliGE                          VALORANT
# 15           EG (S)   Stewie2k                          VALORANT
# 16         NaVi (S)     s1mple                          VALORANT
# 112          T1 (B)      steel                          VALORANT
# 329        100T (C)  seangares                          VALORANT
#
#                                         Mouse Mouse HZ    DPI Sensitivity  \
# 0                       Logitech G100s Custom      500    400         2.0
# 1                Logitech G303 Shroud Edition    1,000    450         2.4
# 2           Logitech G Pro X Superlight Black    1,000    400         2.0
# 32          Logitech G Pro X Superlight White    1,000    400        3.09
# 41          Logitech G Pro X Superlight Black    1,000  1,600        0.74
# 46                    FinalMouse Ultralight 2      500    400        2.35
# 55                     SteelSeries Sensei Ten    1,000    400         1.6
# 97                     HyperX Pulsefire Haste    1,000    400         1.9
# 169         Logitech G Pro X Superlight Black    1,000    800         1.4
# 192                               Zowie EC2-A    1,000    400        3.09
# 367                     SteelSeries Rival 300    1,000  1,600         0.7
# 0                Logitech G303 Shroud Edition    1,000    400         0.8
# 3                       Logitech G100s Custom    1,000    400       0.645
# 10                  FinalMouse Classic Ergo 2    1,000    400       0.741
# 11   FinalMouse Starlight Pro(Small & Medium)    1,000  1,600        0.22
# 12                    Logitech G Pro Wireless    1,000  1,600       0.233
# 15          Logitech G Pro X Superlight Black    1,000    400        0.61
# 16          Logitech G Pro X Superlight White    1,000    400       0.974
# 112                   Razer DeathAdder V3 Pro    1,000    800        0.45
# 329                    HyperX Pulsefire Haste    1,000    800       0.315
#
#       eDPI                 Monitor Monitor HZ             GPU Resolution  \
# 0      800       Alienware AW2521H      360.0        RTX 3090  1920x1080
# 1    1,080       Alienware AW2721D      240.0        RTX 3090  2560x1440
# 2      800            BenQ XL2546K      360.0  RTX 2080 Super   1024x768
# 32   1,236            BenQ XL2546K      240.0        RTX 3090   1280x960
# 41   1,184       Alienware AW2521H      360.0        RTX 3080  1680x1050
# 46     940       Alienware AW2521H      360.0        RTX 3080    800x600
# 55     640             BenQ XL2546      240.0        GTX 1080   1024x768
# 97     760             BenQ XL2546      240.0      GTX 980 Ti  1680x1050
# 169  1,120  ASUS ROG Swift PG259QN      360.0        RTX 3090   1280x960
# 192  1,236            BenQ XL2546K      240.0        RTX 3080   1280x960
# 367  1,120             BenQ XL2546      240.0        RTX 3080  1920x1080
# 0      320       Alienware AW2721D        240        RTX 3090  2560x1440
# 3      258       Alienware AW2521H        240        RTX 3090  1920x1080
# 10     296       Alienware AW2521H        360        RTX 3080  1920x1080
# 11     352            BenQ XL2566K        360        RTX 3090  1920x1080
# 12     372       Alienware AW2518H        240     GTX 1080 Ti  1680x1050
# 15     244       Alienware AW2521H        360     RTX 2080 Ti  1920x1080
# 16     389             BenQ XL2540        240        GTX 1080  1920x1080
# 112    360             BenQ XL2546        240        RTX 3080  1920x1080
# 329    252             BenQ XL2546        240     RTX 2080 Ti  1920x1080
#
#     Aspect Ratio                      Mousepad  \
# 0           16:9         SteelSeries QcK Heavy
# 1           16:9              Logitech G840 SE
# 2            4:3         SteelSeries QcK Heavy
# 32           4:3  HATOR It's nice to be s1mple
# 41         16:10     Lethal Gaming Gear Saturn
# 46           4:3         SteelSeries QcK Heavy
# 55           4:3         SteelSeries QcK Heavy
# 97         16:10             HyperX FURY S Pro
# 169          4:3                 Zowie G-SR-SE
# 192          4:3                    Zowie G-SR
# 367         16:9                 Logitech G640
# 0           16:9              Logitech G840 SE
# 3           16:9                 Logitech G440
# 10          16:9         SteelSeries QcK Heavy
# 11          16:9                    Zowie G-SR
# 12         16:10                    Zowie G-SR
# 15          16:9         SteelSeries QcK Heavy
# 16          16:9                   HATOR INTBS
# 112         16:9             Razer Gigantus V2
# 329         16:9             HyperX FURY S Pro
#
#                                  Keyboard  \
# 0                      HyperX Alloy Elite
# 1                  Logitech G Pro X MK SE
# 2                           Logitech G512
# 32                      Logitech G915 TKL
# 41                      Glorious GMMK Pro
# 46                       SteelSeries 6Gv2
# 55                      Logitech G915 TKL
# 97                   HyperX Alloy FPS RGB
# 169             HyperX Alloy Origins Core
# 192                     Logitech RGB G810
# 367  Logitech G Pro X Mechanical Keyboard
# 0            Logitech G Pro X Keyboard SE
# 3                  Logitech G Pro X MK SE
# 10                       HyperX Alloy FPS
# 11                           Xtrfy K4 TKL
# 12              Massdrop ALT High Profile
# 15                          Logitech G512
# 16   Logitech G Pro X Mechanical Keyboard
# 112                 Razer Huntsman V2 TKL
# 329                      HyperX Alloy FPS
#
#                                   Headset
# 0    Logitech G Pro X Wireless Headset SE
# 1    Logitech G Pro X Wireless Headset SE
# 2                         HyperX Cloud II
# 32               Logitech G Pro X Headset
# 41                Beyerdynamic DT 770 Pro
# 46                Sennheiser GAME ZERO SE
# 55               Logitech G Pro X Headset
# 97                  HyperX Cloud Alpha GE
# 169                  Sennheiser GAME ZERO
# 192              Logitech G Pro X Headset
# 367              Logitech G Pro X Headset
# 0    Logitech G Pro X Wireless Headset SE
# 3    Logitech G Pro X Wireless Headset SE
# 10                        HyperX Cloud II
# 11                               Xtrfy H2
# 12                       Sennheiser PC37X
# 15                        HyperX Cloud II
# 16                       Logitech G Pro X
# 112               Razer BlackShark V2 Pro
# 329                    HyperX Cloud Alpha

# %%
#export data to csv
export_csv = prodata.to_csv(r'prodata_refined.csv',index = None, header = True)

# %%
num = '1,000'
num.replace(',','')
# Out:
# '1000'
