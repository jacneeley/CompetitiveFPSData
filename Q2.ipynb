# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
prodata = pd.read_csv('prodata_refined.csv')
prodata
# Out:
#               Team     Player                              Game  \
# 0         Streamer    n0thing  Counter Strike: Global Offensive
# 1         Streamer     shroud  Counter Strike: Global Offensive
# 2           EG (S)   Stewie2k  Counter Strike: Global Offensive
# 3           Titans        MSL  Counter Strike: Global Offensive
# 4         Vitality     Magisk  Counter Strike: Global Offensive
# ..             ...        ...                               ...
# 737       Streamer  iiTzTimmy                          VALORANT
# 738             FA   governor                          VALORANT
# 739  MAD Lions (B)        xms                          VALORANT
# 740        NIP (B)       xand                          VALORANT
# 741   Heretics (S)    SirMaza                          VALORANT
#
#                                  Mouse Mouse HZ    DPI  Sensitivity   eDPI  \
# 0                Logitech G100s Custom      500    400         2.00    800
# ...

# %%
monitors = prodata.groupby(by=prodata['Monitor']) #Count of monitor used for each game
monitors['Game'].count()
# Out:
# Monitor
# AOC AG251FZ                          9
# AOC AG251FZ2E                        6
# AOC AGON AG241QG                     2
# AOC G2460PF                          2
# ASUS ROG Strix XG248Q                2
# ASUS ROG Swift PG258Q                5
# ASUS ROG Swift PG259QN              25
# ASUS ROG Swift PG279Q                1
# ASUS ROG XG258Q                      2
# ASUS TUF VG258QM                     1
# ASUS TUF VG279QM                     1
# ASUS VG259QM                         3
# Acer Predator XB252Q                 1
# Acer XF250Q                          1
# Alienware AW2518H                   15
# Alienware AW2518HF                   5
# Alienware AW2521H                   16
# Alienware AW2521HF                   8
# Alienware AW2720HF                   1
# Alienware AW2721D                    2
# BenQ XL2411                          4
# BenQ XL2420Z                         1
# BenQ XL2430T                         2
# BenQ XL2540                         80
# ...

# %%
sns.displot(x=prodata['Monitor'], bins=40)

# %%
heights = [50, 100, 150, 200, 250]

plt.bar(monitors['Game'].count(), heights, width= 2.5, color = 'g')
plt.title('Barchart of Monitors Used')
plt.ylabel('Monitor Brand')
plt.xlabel('Count')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [9], in <cell line: 3>()
#       1 heights = [50, 100, 150, 200, 250]
# ----> 3 plt.bar(monitors['Game'].count(), heights, width= 2.5, color = 'g')
#       4 plt.title('Barchart of Monitors Used')
#       5 plt.ylabel('Monitor Brand')
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:2387, in bar(x, height, width, bottom, align, data, **kwargs)
#    2383 @_copy_docstring_and_deprecators(Axes.bar)
#    2384 def bar(
#    2385         x, height, width=0.8, bottom=None, *, align='center',
#    2386         data=None, **kwargs):
# -> 2387     return gca().bar(
#    2388         x, height, width=width, bottom=bottom, align=align,
#    2389         **({"data": data} if data is not None else {}), **kwargs)
#
# ...
